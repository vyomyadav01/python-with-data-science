# %%
import numpy as np
import pandas as pd  
import matplotlib as plt

# %%
dict1 = {
    "name":['vyom','yash','utkarsh','saksham'], 'marks':[92,81,78,17], 'city':['Lucknow','jaipur','goa','shimla'],
}

# %%
df = pd.DataFrame(dict1) #pd.DataFrame converts your data into excel sheet for faster processing like indexing etc

# %%
df
# Out:
#       name  marks     city
# 0     vyom     92  Lucknow
# 1     yash     81   jaipur
# 2  utkarsh     78      goa
# 3  saksham     17   shimla

# %%
df.to_csv('friends.csv')#df.to_csv coverts of code into an excel file

# %%
df.to_csv('friends.csv', index=False) #index = false removes the indexing in excel file

# %%
df.head(2)#shows data from csv file from starting with arguments passed
# Out:
#    name  marks     city
# 0  vyom     92  Lucknow
# 1  yash     81   jaipur

# %%
df.tail(2) #shows data from the end in the csv file
# Out:
#       name  marks    city
# 2  utkarsh     78     goa
# 3  saksham     17  shimla

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   67.000000
# std    33.872309
# min    17.000000
# 25%    62.750000
# 50%    79.500000
# 75%    83.750000
# max    92.000000

# %%
vyom = pd.read_csv('automobile.csv')

# %%
vyom
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
vyom.tail(2)
# Out:
#      Unnamed: 0  symboling normalized-losses   make fuel-type aspiration  \
# 203         203         -1                95  volvo    diesel      turbo
# 204         204         -1                95  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  ...  engine-size  \
# 203         four      sedan          rwd           front  ...          145
# 204         four      sedan          rwd           front  ...          141
#
#      fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  \
# 203          idi  3.01    3.40               23.0        106     4800
# 204         mpfi  3.78    3.15                9.5        114     5400
#
#      city-mpg highway-mpg  price
# 203        26          27  22470
# 204        19          25  22625
#
# [2 rows x 27 columns]

# %%
vyom['engine-size'][0] = 135 # this changes the values in the original sheet
# Out:
# C:\Users\vyomy\AppData\Local\Temp\ipykernel_6356\4987035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vyom['engine-size'][0] = 135 # this changes the values in the original sheet

# %%
vyom
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
vyom.to_csv('vyom ki cardetail.csv')

# %%
vyom
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
df.index = ['first ','second','third','fourth']

# %%
df
# Out:
#            name  marks     city
# first      vyom     92  Lucknow
# second     yash     81   jaipur
# third   utkarsh     78      goa
# fourth  saksham     17   shimla

# %%
ser = pd.Series(np.random.rand(34))

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser
# Out:
# 0     0.390043
# 1     0.188409
# 2     0.424458
# 3     0.629187
# 4     0.509985
# 5     0.446068
# 6     0.589185
# 7     0.394241
# 8     0.518045
# 9     0.696468
# 10    0.006367
# 11    0.736176
# 12    0.521580
# 13    0.525213
# 14    0.749941
# 15    0.976000
# 16    0.772943
# 17    0.865931
# 18    0.247763
# 19    0.132611
# 20    0.539949
# 21    0.255508
# 22    0.556122
# 23    0.584296
# 24    0.968364
# 25    0.319972
# 26    0.981836
# 27    0.593231
# 28    0.564239
# 29    0.387098
# 30    0.110946
# 31    0.253387
# 32    0.039020
# 33    0.873815
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D         E  (0, A)
# 0       654  0.575279  0.482839  0.644278  0.937730     654
# 1  0.065213  0.411883  0.868291  0.395874  0.767786     654
# 2  0.351432  0.859204  0.995885  0.317059  0.614536     654
# 3  0.939003  0.862718  0.825470  0.643826  0.667862     654
# 4  0.777015  0.748075  0.090517  0.121869  0.088227     654

# %%
newdf.loc[:,:]
# Out:
#             A         B         C         D         E  (0, A)
# 0         654  0.575279  0.482839  0.644278  0.937730     654
# 1    0.065213  0.411883  0.868291  0.395874  0.767786     654
# 2    0.351432  0.859204  0.995885  0.317059  0.614536     654
# 3    0.939003  0.862718  0.825470  0.643826  0.667862     654
# 4    0.777015  0.748075  0.090517  0.121869  0.088227     654
# ..        ...       ...       ...       ...       ...     ...
# 329  0.257745  0.135448  0.618078  0.550693  0.344736     654
# 330  0.384747  0.501132  0.131214  0.424586  0.007806     654
# 331  0.200359  0.636471  0.801742  0.634903  0.108576     654
# 332  0.491319  0.119424  0.878688  0.611060  0.054337     654
# 333   0.31619  0.523196  0.355847  0.379840  0.118338     654
#
# [334 rows x 6 columns]

# %%
newdf.iloc[0,4]
# Out:
# 0.9377303383995534

# %%
newdf.iloc[[0,1],[3,4]]
# Out:
#           D         E
# 0  0.644278  0.937730
# 1  0.395874  0.767786

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 333
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       334 non-null    object
#  1   B       334 non-null    float64
#  2   C       334 non-null    float64
#  3   D       334 non-null    float64
#  4   E       334 non-null    float64
#  5   (0, A)  334 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 26.4+ KB

# %%
newdf
# Out:
#             A         B         C         D         E  (0, A)
# 0         654  0.575279  0.482839  0.644278  0.937730     654
# 1    0.065213  0.411883  0.868291  0.395874  0.767786     654
# 2    0.351432  0.859204  0.995885  0.317059  0.614536     654
# 3    0.939003  0.862718  0.825470  0.643826  0.667862     654
# 4    0.777015  0.748075  0.090517  0.121869  0.088227     654
# ..        ...       ...       ...       ...       ...     ...
# 329  0.257745  0.135448  0.618078  0.550693  0.344736     654
# 330  0.384747  0.501132  0.131214  0.424586  0.007806     654
# 331  0.200359  0.636471  0.801742  0.634903  0.108576     654
# 332  0.491319  0.119424  0.878688  0.611060  0.054337     654
# 333   0.31619  0.523196  0.355847  0.379840  0.118338     654
#
# [334 rows x 6 columns]

# %% [markdown]
# ` how to select perticular row or column from data

# %%
newdf['A'].head()
# Out:
# 0         654
# 1    0.065213
# 2    0.351432
# 3    0.939003
# 4    0.777015
# Name: A, dtype: object

# %%
newdf['A']
# Out:
# 0           654
# 1      0.065213
# 2      0.351432
# 3      0.939003
# 4      0.777015
#          ...
# 329    0.257745
# 330    0.384747
# 331    0.200359
# 332    0.491319
# 333     0.31619
# Name: A, Length: 334, dtype: object

# %%
newdf[0:1]
# Out:
#      A         B         C         D        E  (0, A)
# 0  654  0.575279  0.482839  0.644278  0.93773     654

# %% [markdown]
# # select perticular row from data

# %%
newdf.head(1)
# Out:
#      A         B         C         D        E  (0, A)
# 0  654  0.575279  0.482839  0.644278  0.93773     654

# %% [markdown]
# # drop perticular row or column from data

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E  (0, A)
# 1    0.065213  0.411883  0.868291  0.395874  0.767786     654
# 2    0.351432  0.859204  0.995885  0.317059  0.614536     654
# 3    0.939003  0.862718  0.825470  0.643826  0.667862     654
# 4    0.777015  0.748075  0.090517  0.121869  0.088227     654
# 5    0.208238  0.752398  0.072516  0.672131  0.342285     654
# ..        ...       ...       ...       ...       ...     ...
# 329  0.257745  0.135448  0.618078  0.550693  0.344736     654
# 330  0.384747  0.501132  0.131214  0.424586  0.007806     654
# 331  0.200359  0.636471  0.801742  0.634903  0.108576     654
# 332  0.491319  0.119424  0.878688  0.611060  0.054337     654
# 333   0.31619  0.523196  0.355847  0.379840  0.118338     654
#
# [333 rows x 6 columns]

# %% [markdown]
# ``` drop perticular column from table ```

# %%
newdf.drop(['A'], axis=1, inplace=True) # inplace changes the data in the original data base

# %%
newdf
# Out:
#             B         C         D         E  (0, A)
# 0    0.575279  0.482839  0.644278  0.937730     654
# 1    0.411883  0.868291  0.395874  0.767786     654
# 2    0.859204  0.995885  0.317059  0.614536     654
# 3    0.862718  0.825470  0.643826  0.667862     654
# 4    0.748075  0.090517  0.121869  0.088227     654
# ..        ...       ...       ...       ...     ...
# 329  0.135448  0.618078  0.550693  0.344736     654
# 330  0.501132  0.131214  0.424586  0.007806     654
# 331  0.636471  0.801742  0.634903  0.108576     654
# 332  0.119424  0.878688  0.611060  0.054337     654
# 333  0.523196  0.355847  0.379840  0.118338     654
#
# [334 rows x 5 columns]

# %%
newdf.head(3)
# Out:
#           B         C         D         E  (0, A)
# 0  0.575279  0.482839  0.644278  0.937730     654
# 1  0.411883  0.868291  0.395874  0.767786     654
# 2  0.859204  0.995885  0.317059  0.614536     654

# %% [markdown]
# ``` as we have dropped the column in our data so our indexing is quite messed up so to re index it we use reindex functiom ```

# %%
newdf.reset_index()
# Out:
#      index         B         C         D         E  (0, A)
# 0        0  0.575279  0.482839  0.644278  0.937730     654
# 1        1  0.411883  0.868291  0.395874  0.767786     654
# 2        2  0.859204  0.995885  0.317059  0.614536     654
# 3        3  0.862718  0.825470  0.643826  0.667862     654
# 4        4  0.748075  0.090517  0.121869  0.088227     654
# ..     ...       ...       ...       ...       ...     ...
# 329    329  0.135448  0.618078  0.550693  0.344736     654
# 330    330  0.501132  0.131214  0.424586  0.007806     654
# 331    331  0.636471  0.801742  0.634903  0.108576     654
# 332    332  0.119424  0.878688  0.611060  0.054337     654
# 333    333  0.523196  0.355847  0.379840  0.118338     654
#
# [334 rows x 6 columns]

# %%
newdf.reset_index(drop=True, inplace=True) # inplace makes changes or overwrite our changes in our main datatable

# %%
print(newdf.columns.tolist()) # how to print perticular comumns first convert data into to list and then print perticular data
# Out:
# ['B', 'C', 'D', 'E', (0, 'A')]

# %%
newdf['B']
# Out:
# 0      0.575279
# 1      0.411883
# 2      0.859204
# 3      0.862718
# 4      0.748075
#          ...
# 329    0.135448
# 330    0.501132
# 331    0.636471
# 332    0.119424
# 333    0.523196
# Name: B, Length: 334, dtype: float64

# %%
vyom
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...
