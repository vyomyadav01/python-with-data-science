# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
pd.set_option('display.max_colum',None)

# %%
df = pd.read_csv('automobile.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
# 2   65.5    52.4         2823        ohcv              six          152
# 3   66.2    54.3         2337         ohc             four          109
# 4   66.4    54.3         2824         ohc             five          136
#
#   fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0        mpfi  3.47   2.68                9.0        111     5000        21
# 1        mpfi  3.47   2.68                9.0        111     5000        21
# 2        mpfi  2.68   3.47                9.0        154     5000        19
# 3        mpfi  3.19   3.40               10.0        102     5500        24
# 4        mpfi  3.19   3.40                8.0        115     5500        18
#
#    highway-mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# 3           30  13950
# 4           22  17450

# %%
df
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# 0          std          two  convertible          rwd           front
# 1          std          two  convertible          rwd           front
# 2          std          two    hatchback          rwd           front
# 3          std         four        sedan          fwd           front
# 4          std         four        sedan          4wd           front
# ..         ...          ...          ...          ...             ...
# 200        std         four        sedan          rwd           front
# 201      turbo         four        sedan          rwd           front
# 202        std         four        sedan          rwd           front
# 203      turbo         four        sedan          rwd           front
# 204      turbo         four        sedan          rwd           front
#
#      wheel-base  length  width  height  curb-weight engine-type  \
# 0          88.6   168.8   64.1    48.8         2548        dohc
# 1          88.6   168.8   64.1    48.8         2548        dohc
# 2          94.5   171.2   65.5    52.4         2823        ohcv
# 3          99.8   176.6   66.2    54.3         2337         ohc
# 4          99.4   176.6   66.4    54.3         2824         ohc
# ..          ...     ...    ...     ...          ...         ...
# 200       109.1   188.8   68.9    55.5         2952         ohc
# 201       109.1   188.8   68.8    55.5         3049         ohc
# 202       109.1   188.8   68.9    55.5         3012        ohcv
# 203       109.1   188.8   68.9    55.5         3217         ohc
# 204       109.1   188.8   68.9    55.5         3062         ohc
#
#     num-of-cylinders  engine-size fuel-system  bore stroke  compression-ratio  \
# 0               four          130        mpfi  3.47   2.68                9.0
# 1               four          130        mpfi  3.47   2.68                9.0
# 2                six          152        mpfi  2.68   3.47                9.0
# 3               four          109        mpfi  3.19   3.40               10.0
# 4               five          136        mpfi  3.19   3.40                8.0
# ..               ...          ...         ...   ...    ...                ...
# 200             four          141        mpfi  3.78   3.15                9.5
# 201             four          141        mpfi  3.78   3.15                8.7
# 202              six          173        mpfi  3.58   2.87                8.8
# 203              six          145         idi  3.01   3.40               23.0
# 204             four          141        mpfi  3.78   3.15                9.5
#
#     horsepower peak-rpm  city-mpg  highway-mpg  price
# 0          111     5000        21           27  13495
# 1          111     5000        21           27  16500
# 2          154     5000        19           26  16500
# 3          102     5500        24           30  13950
# 4          115     5500        18           22  17450
# ..         ...      ...       ...          ...    ...
# 200        114     5400        23           28  16845
# 201        160     5300        19           25  19045
# 202        134     5500        18           23  21485
# 203        106     4800        26           27  22470
# 204        114     5400        19           25  22625
#
# [205 rows x 27 columns]

# %%
df.head(10)
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
# 5           5          2                 ?         audi       gas        std
# 6           6          1               158         audi       gas        std
# 7           7          1                 ?         audi       gas        std
# 8           8          1               158         audi       gas      turbo
# 9           9          0                 ?         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
# 5          two        sedan          fwd           front        99.8   177.3
# 6         four        sedan          fwd           front       105.8   192.7
# 7         four        wagon          fwd           front       105.8   192.7
# 8         four        sedan          fwd           front       105.8   192.7
# 9          two    hatchback          4wd           front        99.5   178.2
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
# 2   65.5    52.4         2823        ohcv              six          152
# 3   66.2    54.3         2337         ohc             four          109
# 4   66.4    54.3         2824         ohc             five          136
# 5   66.3    53.1         2507         ohc             five          136
# 6   71.4    55.7         2844         ohc             five          136
# 7   71.4    55.7         2954         ohc             five          136
# 8   71.4    55.9         3086         ohc             five          131
# 9   67.9    52.0         3053         ohc             five          131
#
#   fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0        mpfi  3.47   2.68                9.0        111     5000        21
# 1        mpfi  3.47   2.68                9.0        111     5000        21
# 2        mpfi  2.68   3.47                9.0        154     5000        19
# 3        mpfi  3.19   3.40               10.0        102     5500        24
# 4        mpfi  3.19   3.40                8.0        115     5500        18
# 5        mpfi  3.19   3.40                8.5        110     5500        19
# 6        mpfi  3.19   3.40                8.5        110     5500        19
# 7        mpfi  3.19   3.40                8.5        110     5500        19
# 8        mpfi  3.13   3.40                8.3        140     5500        17
# 9        mpfi  3.13   3.40                7.0        160     5500        16
#
#    highway-mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# 3           30  13950
# 4           22  17450
# 5           25  15250
# 6           25  17710
# 7           25  18920
# 8           20  23875
# 9           22      ?

# %%
df.tail(10)
# Out:
#      Unnamed: 0  symboling normalized-losses   make fuel-type aspiration  \
# 195         195         -1                74  volvo       gas        std
# 196         196         -2               103  volvo       gas        std
# 197         197         -1                74  volvo       gas        std
# 198         198         -2               103  volvo       gas      turbo
# 199         199         -1                74  volvo       gas      turbo
# 200         200         -1                95  volvo       gas        std
# 201         201         -1                95  volvo       gas      turbo
# 202         202         -1                95  volvo       gas        std
# 203         203         -1                95  volvo    diesel      turbo
# 204         204         -1                95  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  length  \
# 195         four      wagon          rwd           front       104.3   188.8
# 196         four      sedan          rwd           front       104.3   188.8
# 197         four      wagon          rwd           front       104.3   188.8
# 198         four      sedan          rwd           front       104.3   188.8
# 199         four      wagon          rwd           front       104.3   188.8
# 200         four      sedan          rwd           front       109.1   188.8
# 201         four      sedan          rwd           front       109.1   188.8
# 202         four      sedan          rwd           front       109.1   188.8
# 203         four      sedan          rwd           front       109.1   188.8
# 204         four      sedan          rwd           front       109.1   188.8
#
#      width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 195   67.2    57.5         3034         ohc             four          141
# 196   67.2    56.2         2935         ohc             four          141
# 197   67.2    57.5         3042         ohc             four          141
# 198   67.2    56.2         3045         ohc             four          130
# 199   67.2    57.5         3157         ohc             four          130
# 200   68.9    55.5         2952         ohc             four          141
# 201   68.8    55.5         3049         ohc             four          141
# 202   68.9    55.5         3012        ohcv              six          173
# 203   68.9    55.5         3217         ohc              six          145
# 204   68.9    55.5         3062         ohc             four          141
#
#     fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 195        mpfi  3.78   3.15                9.5        114     5400        23
# 196        mpfi  3.78   3.15                9.5        114     5400        24
# 197        mpfi  3.78   3.15                9.5        114     5400        24
# 198        mpfi  3.62   3.15                7.5        162     5100        17
# 199        mpfi  3.62   3.15                7.5        162     5100        17
# 200        mpfi  3.78   3.15                9.5        114     5400        23
# 201        mpfi  3.78   3.15                8.7        160     5300        19
# 202        mpfi  3.58   2.87                8.8        134     5500        18
# 203         idi  3.01   3.40               23.0        106     4800        26
# 204        mpfi  3.78   3.15                9.5        114     5400        19
#
#      highway-mpg  price
# 195           28  13415
# 196           28  15985
# 197           28  16515
# 198           22  18420
# 199           22  18950
# 200           28  16845
# 201           25  19045
# 202           23  21485
# 203           27  22470
# 204           25  22625

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         205 non-null    int64
#  1   symboling          205 non-null    int64
#  2   normalized-losses  205 non-null    object
#  3   make               205 non-null    object
#  4   fuel-type          205 non-null    object
#  5   aspiration         205 non-null    object
#  6   num-of-doors       205 non-null    object
#  7   body-style         205 non-null    object
#  8   drive-wheels       205 non-null    object
#  9   engine-location    205 non-null    object
#  10  wheel-base         205 non-null    float64
#  11  length             205 non-null    float64
#  12  width              205 non-null    float64
#  13  height             205 non-null    float64
#  14  curb-weight        205 non-null    int64
#  15  engine-type        205 non-null    object
#  16  num-of-cylinders   205 non-null    object
#  17  engine-size        205 non-null    int64
#  18  fuel-system        205 non-null    object
#  19  bore               205 non-null    object
#  20  stroke             205 non-null    object
#  21  compression-ratio  205 non-null    float64
#  22  horsepower         205 non-null    object
#  23  peak-rpm           205 non-null    object
#  24  city-mpg           205 non-null    int64
#  25  highway-mpg        205 non-null    int64
#  26  price              205 non-null    object
# dtypes: float64(5), int64(6), object(16)
# memory usage: 43.4+ KB

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
df['symboling']
# Out:
# 0      3
# 1      3
# 2      1
# 3      2
# 4      2
#       ..
# 200   -1
# 201   -1
# 202   -1
# 203   -1
# 204   -1
# Name: symboling, Length: 205, dtype: int64

# %%
col_list = ['make', 'body-style']
df[col_list]
# Out:
#             make   body-style
# 0    alfa-romero  convertible
# 1    alfa-romero  convertible
# 2    alfa-romero    hatchback
# 3           audi        sedan
# 4           audi        sedan
# ..           ...          ...
# 200        volvo        sedan
# 201        volvo        sedan
# 202        volvo        sedan
# 203        volvo        sedan
# 204        volvo        sedan
#
# [205 rows x 2 columns]

# %%
df
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# 0          std          two  convertible          rwd           front
# 1          std          two  convertible          rwd           front
# 2          std          two    hatchback          rwd           front
# 3          std         four        sedan          fwd           front
# 4          std         four        sedan          4wd           front
# ..         ...          ...          ...          ...             ...
# 200        std         four        sedan          rwd           front
# 201      turbo         four        sedan          rwd           front
# 202        std         four        sedan          rwd           front
# 203      turbo         four        sedan          rwd           front
# 204      turbo         four        sedan          rwd           front
#
#      wheel-base  length  width  height  curb-weight engine-type  \
# 0          88.6   168.8   64.1    48.8         2548        dohc
# 1          88.6   168.8   64.1    48.8         2548        dohc
# 2          94.5   171.2   65.5    52.4         2823        ohcv
# 3          99.8   176.6   66.2    54.3         2337         ohc
# 4          99.4   176.6   66.4    54.3         2824         ohc
# ..          ...     ...    ...     ...          ...         ...
# 200       109.1   188.8   68.9    55.5         2952         ohc
# 201       109.1   188.8   68.8    55.5         3049         ohc
# 202       109.1   188.8   68.9    55.5         3012        ohcv
# 203       109.1   188.8   68.9    55.5         3217         ohc
# 204       109.1   188.8   68.9    55.5         3062         ohc
#
#     num-of-cylinders  engine-size fuel-system  bore stroke  compression-ratio  \
# 0               four          130        mpfi  3.47   2.68                9.0
# 1               four          130        mpfi  3.47   2.68                9.0
# 2                six          152        mpfi  2.68   3.47                9.0
# 3               four          109        mpfi  3.19   3.40               10.0
# 4               five          136        mpfi  3.19   3.40                8.0
# ..               ...          ...         ...   ...    ...                ...
# 200             four          141        mpfi  3.78   3.15                9.5
# 201             four          141        mpfi  3.78   3.15                8.7
# 202              six          173        mpfi  3.58   2.87                8.8
# 203              six          145         idi  3.01   3.40               23.0
# 204             four          141        mpfi  3.78   3.15                9.5
#
#     horsepower peak-rpm  city-mpg  highway-mpg  price
# 0          111     5000        21           27  13495
# 1          111     5000        21           27  16500
# 2          154     5000        19           26  16500
# 3          102     5500        24           30  13950
# 4          115     5500        18           22  17450
# ..         ...      ...       ...          ...    ...
# 200        114     5400        23           28  16845
# 201        160     5300        19           25  19045
# 202        134     5500        18           23  21485
# 203        106     4800        26           27  22470
# 204        114     5400        19           25  22625
#
# [205 rows x 27 columns]

# %%
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
df['make'].value_counts().plot(kind='bar', figsize=(15,5), title='Automobile brands')
# Out:
# <AxesSubplot: title={'center': 'Automobile brands'}>

# %%
df.rename(mapper={"make":"brand"}, axis=1, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
# 2   65.5    52.4         2823        ohcv              six          152
# 3   66.2    54.3         2337         ohc             four          109
# 4   66.4    54.3         2824         ohc             five          136
#
#   fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0        mpfi  3.47   2.68                9.0        111     5000        21
# 1        mpfi  3.47   2.68                9.0        111     5000        21
# 2        mpfi  2.68   3.47                9.0        154     5000        19
# 3        mpfi  3.19   3.40               10.0        102     5500        24
# 4        mpfi  3.19   3.40                8.0        115     5500        18
#
#    highway-mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# 3           30  13950
# 4           22  17450

# %% [markdown]
# # column drop

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses        brand fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df.replace('alfa-romero', 'alfa-romeo',inplace=True)

# %%
df
# Out:
#      symboling normalized-losses       brand fuel-type aspiration  \
# 0            3                 ?  alfa-romeo       gas        std
# 1            3                 ?  alfa-romeo       gas        std
# 2            1                 ?  alfa-romeo       gas        std
# 3            2               164        audi       gas        std
# 4            2               164        audi       gas        std
# ..         ...               ...         ...       ...        ...
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# 203         -1                95       volvo    diesel      turbo
# 204         -1                95       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# 1            two  convertible          rwd           front        88.6
# 2            two    hatchback          rwd           front        94.5
# 3           four        sedan          fwd           front        99.8
# 4           four        sedan          4wd           front        99.4
# ..           ...          ...          ...             ...         ...
# 200         four        sedan          rwd           front       109.1
# 201         four        sedan          rwd           front       109.1
# 202         four        sedan          rwd           front       109.1
# 203         four        sedan          rwd           front       109.1
# 204         four        sedan          rwd           front       109.1
#
#      length  width  height  curb-weight engine-type num-of-cylinders  \
# 0     168.8   64.1    48.8         2548        dohc             four
# 1     168.8   64.1    48.8         2548        dohc             four
# 2     171.2   65.5    52.4         2823        ohcv              six
# 3     176.6   66.2    54.3         2337         ohc             four
# 4     176.6   66.4    54.3         2824         ohc             five
# ..      ...    ...     ...          ...         ...              ...
# 200   188.8   68.9    55.5         2952         ohc             four
# 201   188.8   68.8    55.5         3049         ohc             four
# 202   188.8   68.9    55.5         3012        ohcv              six
# 203   188.8   68.9    55.5         3217         ohc              six
# 204   188.8   68.9    55.5         3062         ohc             four
#
#      engine-size fuel-system  bore stroke  compression-ratio horsepower  \
# 0            130        mpfi  3.47   2.68                9.0        111
# 1            130        mpfi  3.47   2.68                9.0        111
# 2            152        mpfi  2.68   3.47                9.0        154
# 3            109        mpfi  3.19   3.40               10.0        102
# 4            136        mpfi  3.19   3.40                8.0        115
# ..           ...         ...   ...    ...                ...        ...
# 200          141        mpfi  3.78   3.15                9.5        114
# 201          141        mpfi  3.78   3.15                8.7        160
# 202          173        mpfi  3.58   2.87                8.8        134
# 203          145         idi  3.01   3.40               23.0        106
# 204          141        mpfi  3.78   3.15                9.5        114
#
#     peak-rpm  city-mpg  highway-mpg  price
# 0       5000        21           27  13495
# 1       5000        21           27  16500
# 2       5000        19           26  16500
# 3       5500        24           30  13950
# 4       5500        18           22  17450
# ..       ...       ...          ...    ...
# 200     5400        23           28  16845
# 201     5300        19           25  19045
# 202     5500        18           23  21485
# 203     4800        26           27  22470
# 204     5400        19           25  22625
#
# [205 rows x 26 columns]

# %%
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romeo       gas        std          two
# 1          3                 ?  alfa-romeo       gas        std          two
# 2          1                 ?  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df.replace('?', np.nan, inplace=True)

# %%
df
# Out:
#      symboling normalized-losses       brand fuel-type aspiration  \
# 0            3               NaN  alfa-romeo       gas        std
# 1            3               NaN  alfa-romeo       gas        std
# 2            1               NaN  alfa-romeo       gas        std
# 3            2               164        audi       gas        std
# 4            2               164        audi       gas        std
# ..         ...               ...         ...       ...        ...
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# 203         -1                95       volvo    diesel      turbo
# 204         -1                95       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# 1            two  convertible          rwd           front        88.6
# 2            two    hatchback          rwd           front        94.5
# 3           four        sedan          fwd           front        99.8
# 4           four        sedan          4wd           front        99.4
# ..           ...          ...          ...             ...         ...
# 200         four        sedan          rwd           front       109.1
# 201         four        sedan          rwd           front       109.1
# 202         four        sedan          rwd           front       109.1
# 203         four        sedan          rwd           front       109.1
# 204         four        sedan          rwd           front       109.1
#
#      length  width  height  curb-weight engine-type num-of-cylinders  \
# 0     168.8   64.1    48.8         2548        dohc             four
# 1     168.8   64.1    48.8         2548        dohc             four
# 2     171.2   65.5    52.4         2823        ohcv              six
# 3     176.6   66.2    54.3         2337         ohc             four
# 4     176.6   66.4    54.3         2824         ohc             five
# ..      ...    ...     ...          ...         ...              ...
# 200   188.8   68.9    55.5         2952         ohc             four
# 201   188.8   68.8    55.5         3049         ohc             four
# 202   188.8   68.9    55.5         3012        ohcv              six
# 203   188.8   68.9    55.5         3217         ohc              six
# 204   188.8   68.9    55.5         3062         ohc             four
#
#      engine-size fuel-system  bore stroke  compression-ratio horsepower  \
# 0            130        mpfi  3.47   2.68                9.0        111
# 1            130        mpfi  3.47   2.68                9.0        111
# 2            152        mpfi  2.68   3.47                9.0        154
# 3            109        mpfi  3.19   3.40               10.0        102
# 4            136        mpfi  3.19   3.40                8.0        115
# ..           ...         ...   ...    ...                ...        ...
# 200          141        mpfi  3.78   3.15                9.5        114
# 201          141        mpfi  3.78   3.15                8.7        160
# 202          173        mpfi  3.58   2.87                8.8        134
# 203          145         idi  3.01   3.40               23.0        106
# 204          141        mpfi  3.78   3.15                9.5        114
#
#     peak-rpm  city-mpg  highway-mpg  price
# 0       5000        21           27  13495
# 1       5000        21           27  16500
# 2       5000        19           26  16500
# 3       5500        24           30  13950
# 4       5500        18           22  17450
# ..       ...       ...          ...    ...
# 200     5400        23           28  16845
# 201     5300        19           25  19045
# 202     5500        18           23  21485
# 203     4800        26           27  22470
# 204     5400        19           25  22625
#
# [205 rows x 26 columns]

# %%
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romeo       gas        std          two
# 1          3               NaN  alfa-romeo       gas        std          two
# 2          1               NaN  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df.dropna(subset=['price'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   brand              205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               201 non-null    object
#  19  stroke             201 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         203 non-null    object
#  22  peak-rpm           203 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              201 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
df.isnull().sum() #count the number of missing data in each column
# Out:
# symboling             0
# normalized-losses    41
# brand                 0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df['normalized-losses'].astype('float').sum()
# Out:
# 20008.0

# %%
mnl = df['normalized-losses'].astype('float').mean()

# %%
df['normalized-losses'].replace(np.nan, mnl, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romeo       gas        std          two
# 1          3             122.0  alfa-romeo       gas        std          two
# 2          1             122.0  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df['bore'].replace(np.nan, mnl, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romeo       gas        std          two
# 1          3             122.0  alfa-romeo       gas        std          two
# 2          1             122.0  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   brand              205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             201 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         203 non-null    object
#  22  peak-rpm           203 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              201 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
mnl = df['stroke'].astype('float').mean()

# %%
mnl = df['horsepower'].astype('float').mean()

# %%
df['horsepower'].replace(np.nan, mnl, inplace=True)

# %%
df['stroke'].replace(np.nan, mnl, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romeo       gas        std          two
# 1          3             122.0  alfa-romeo       gas        std          two
# 2          1             122.0  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# brand                0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df
# Out:
#      symboling normalized-losses       brand fuel-type aspiration  \
# 0            3             122.0  alfa-romeo       gas        std
# 1            3             122.0  alfa-romeo       gas        std
# 2            1             122.0  alfa-romeo       gas        std
# 3            2               164        audi       gas        std
# 4            2               164        audi       gas        std
# ..         ...               ...         ...       ...        ...
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# 203         -1                95       volvo    diesel      turbo
# 204         -1                95       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# 1            two  convertible          rwd           front        88.6
# 2            two    hatchback          rwd           front        94.5
# 3           four        sedan          fwd           front        99.8
# 4           four        sedan          4wd           front        99.4
# ..           ...          ...          ...             ...         ...
# 200         four        sedan          rwd           front       109.1
# 201         four        sedan          rwd           front       109.1
# 202         four        sedan          rwd           front       109.1
# 203         four        sedan          rwd           front       109.1
# 204         four        sedan          rwd           front       109.1
#
#      length  width  height  curb-weight engine-type num-of-cylinders  \
# 0     168.8   64.1    48.8         2548        dohc             four
# 1     168.8   64.1    48.8         2548        dohc             four
# 2     171.2   65.5    52.4         2823        ohcv              six
# 3     176.6   66.2    54.3         2337         ohc             four
# 4     176.6   66.4    54.3         2824         ohc             five
# ..      ...    ...     ...          ...         ...              ...
# 200   188.8   68.9    55.5         2952         ohc             four
# 201   188.8   68.8    55.5         3049         ohc             four
# 202   188.8   68.9    55.5         3012        ohcv              six
# 203   188.8   68.9    55.5         3217         ohc              six
# 204   188.8   68.9    55.5         3062         ohc             four
#
#      engine-size fuel-system  bore stroke  compression-ratio horsepower  \
# 0            130        mpfi  3.47   2.68                9.0        111
# 1            130        mpfi  3.47   2.68                9.0        111
# 2            152        mpfi  2.68   3.47                9.0        154
# 3            109        mpfi  3.19   3.40               10.0        102
# 4            136        mpfi  3.19   3.40                8.0        115
# ..           ...         ...   ...    ...                ...        ...
# 200          141        mpfi  3.78   3.15                9.5        114
# 201          141        mpfi  3.78   3.15                8.7        160
# 202          173        mpfi  3.58   2.87                8.8        134
# 203          145         idi  3.01   3.40               23.0        106
# 204          141        mpfi  3.78   3.15                9.5        114
#
#     peak-rpm  city-mpg  highway-mpg  price
# 0       5000        21           27  13495
# 1       5000        21           27  16500
# 2       5000        19           26  16500
# 3       5500        24           30  13950
# 4       5500        18           22  17450
# ..       ...       ...          ...    ...
# 200     5400        23           28  16845
# 201     5300        19           25  19045
# 202     5500        18           23  21485
# 203     4800        26           27  22470
# 204     5400        19           25  22625
#
# [201 rows x 26 columns]

# %%
df['num-of-doors'].value_counts()
# Out:
# four    113
# two      86
# Name: num-of-doors, dtype: int64

# %%
df['num-of-doors'].replace(np.nan, 'four', inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romeo       gas        std          two
# 1          3             122.0  alfa-romeo       gas        std          two
# 2          1             122.0  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# brand                0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.to_csv('automobile_cleaned.csv', index=False)

# %%
df.T
# Out:
#                            0            1           2      3      4      5    \
# symboling                    3            3           1      2      2      2
# normalized-losses        122.0        122.0       122.0    164    164  122.0
# brand               alfa-romeo   alfa-romeo  alfa-romeo   audi   audi   audi
# fuel-type                  gas          gas         gas    gas    gas    gas
# aspiration                 std          std         std    std    std    std
# num-of-doors               two          two         two   four   four    two
# body-style         convertible  convertible   hatchback  sedan  sedan  sedan
# drive-wheels               rwd          rwd         rwd    fwd    4wd    fwd
# engine-location          front        front       front  front  front  front
# wheel-base                88.6         88.6        94.5   99.8   99.4   99.8
# length                   168.8        168.8       171.2  176.6  176.6  177.3
# width                     64.1         64.1        65.5   66.2   66.4   66.3
# height                    48.8         48.8        52.4   54.3   54.3   53.1
# curb-weight               2548         2548        2823   2337   2824   2507
# engine-type               dohc         dohc        ohcv    ohc    ohc    ohc
# num-of-cylinders          four         four         six   four   five   five
# engine-size                130          130         152    109    136    136
# fuel-system               mpfi         mpfi        mpfi   mpfi   mpfi   mpfi
# bore                      3.47         3.47        2.68   3.19   3.19   3.19
# stroke                    2.68         2.68        3.47   3.40   3.40   3.40
# compression-ratio          9.0          9.0         9.0   10.0    8.0    8.5
# horsepower                 111          111         154    102    115    110
# peak-rpm                  5000         5000        5000   5500   5500   5500
# city-mpg                    21           21          19     24     18     19
# highway-mpg                 27           27          26     30     22     25
# price                    13495        16500       16500  13950  17450  15250
#
#                      6      7      8      10     11     12     13     14   \
# symboling              1      1      1      2      0      0      0      1
# normalized-losses    158  122.0    158    192    192    188    188  122.0
# brand               audi   audi   audi    bmw    bmw    bmw    bmw    bmw
# fuel-type            gas    gas    gas    gas    gas    gas    gas    gas
# aspiration           std    std  turbo    std    std    std    std    std
# num-of-doors        four   four   four    two   four    two   four   four
# body-style         sedan  wagon  sedan  sedan  sedan  sedan  sedan  sedan
# drive-wheels         fwd    fwd    fwd    rwd    rwd    rwd    rwd    rwd
# engine-location    front  front  front  front  front  front  front  front
# wheel-base         105.8  105.8  105.8  101.2  101.2  101.2  101.2  103.5
# length             192.7  192.7  192.7  176.8  176.8  176.8  176.8  189.0
# width               71.4   71.4   71.4   64.8   64.8   64.8   64.8   66.9
# height              55.7   55.7   55.9   54.3   54.3   54.3   54.3   55.7
# curb-weight         2844   2954   3086   2395   2395   2710   2765   3055
# engine-type          ohc    ohc    ohc    ohc    ohc    ohc    ohc    ohc
# num-of-cylinders    five   five   five   four   four    six    six    six
# engine-size          136    136    131    108    108    164    164    164
# fuel-system         mpfi   mpfi   mpfi   mpfi   mpfi   mpfi   mpfi   mpfi
# bore                3.19   3.19   3.13   3.50   3.50   3.31   3.31   3.31
# stroke              3.40   3.40   3.40   2.80   2.80   3.19   3.19   3.19
# compression-ratio    8.5    8.5    8.3    8.8    8.8    9.0    9.0    9.0
# horsepower           110    110    140    101    101    121    121    121
# peak-rpm            5500   5500   5500   5800   5800   4250   4250   4250
# city-mpg              19     19     17     23     23     21     21     20
# highway-mpg           25     25     20     29     29     28     28     25
# price              17710  18920  23875  16430  16925  20970  21105  24565
#
#                      15     16     17         18         19         20   \
# symboling              0      0      0          2          1          0
# normalized-losses  122.0  122.0  122.0        121         98         81
# brand                bmw    bmw    bmw  chevrolet  chevrolet  chevrolet
# fuel-type            gas    gas    gas        gas        gas        gas
# aspiration           std    std    std        std        std        std
# num-of-doors        four    two   four        two        two       four
# body-style         sedan  sedan  sedan  hatchback  hatchback      sedan
# drive-wheels         rwd    rwd    rwd        fwd        fwd        fwd
# engine-location    front  front  front      front      front      front
# wheel-base         103.5  103.5  110.0       88.4       94.5       94.5
# length             189.0  193.8  197.0      141.1      155.9      158.8
# width               66.9   67.9   70.9       60.3       63.6       63.6
# height              55.7   53.7   56.3       53.2       52.0       52.0
# curb-weight         3230   3380   3505       1488       1874       1909
# engine-type          ohc    ohc    ohc          l        ohc        ohc
# num-of-cylinders     six    six    six      three       four       four
# engine-size          209    209    209         61         90         90
# fuel-system         mpfi   mpfi   mpfi       2bbl       2bbl       2bbl
# bore                3.62   3.62   3.62       2.91       3.03       3.03
# stroke              3.39   3.39   3.39       3.03       3.11       3.11
# compression-ratio    8.0    8.0    8.0        9.5        9.6        9.6
# horsepower           182    182    182         48         70         70
# peak-rpm            5400   5400   5400       5100       5400       5400
# city-mpg              16     16     15         47         38         38
# highway-mpg           22     22     20         53         43         43
# price              30760  41315  36880       5151       6295       6575
#
#                          21         22         23         24     25     26   \
# symboling                  1          1          1          1      1      1
# normalized-losses        118        118        118        148    148    148
# brand                  dodge      dodge      dodge      dodge  dodge  dodge
# fuel-type                gas        gas        gas        gas    gas    gas
# aspiration               std        std      turbo        std    std    std
# num-of-doors             two        two        two       four   four   four
# body-style         hatchback  hatchback  hatchback  hatchback  sedan  sedan
# drive-wheels             fwd        fwd        fwd        fwd    fwd    fwd
# engine-location        front      front      front      front  front  front
# wheel-base              93.7       93.7       93.7       93.7   93.7   93.7
# length                 157.3      157.3      157.3      157.3  157.3  157.3
# width                   63.8       63.8       63.8       63.8   63.8   63.8
# height                  50.8       50.8       50.8       50.6   50.6   50.6
# curb-weight             1876       1876       2128       1967   1989   1989
# engine-type              ohc        ohc        ohc        ohc    ohc    ohc
# num-of-cylinders        four       four       four       four   four   four
# engine-size               90         90         98         90     90     90
# fuel-system             2bbl       2bbl       mpfi       2bbl   2bbl   2bbl
# bore                    2.97       2.97       3.03       2.97   2.97   2.97
# stroke                  3.23       3.23       3.39       3.23   3.23   3.23
# compression-ratio       9.41        9.4        7.6        9.4    9.4    9.4
# horsepower                68         68        102         68     68     68
# peak-rpm                5500       5500       5500       5500   5500   5500
# city-mpg                  37         31         24         31     31     31
# highway-mpg               41         38         30         38     38     38
# price                   5572       6377       7957       6229   6692   7609
#
#                      27     28         29         30         31         32   \
# symboling              1     -1          3          2          2          1
# normalized-losses    148    110        145        137        137        101
# brand              dodge  dodge      dodge      honda      honda      honda
# fuel-type            gas    gas        gas        gas        gas        gas
# aspiration         turbo    std      turbo        std        std        std
# num-of-doors        four   four        two        two        two        two
# body-style         sedan  wagon  hatchback  hatchback  hatchback  hatchback
# drive-wheels         fwd    fwd        fwd        fwd        fwd        fwd
# engine-location    front  front      front      front      front      front
# wheel-base          93.7  103.3       95.9       86.6       86.6       93.7
# length             157.3  174.6      173.2      144.6      144.6      150.0
# width               63.8   64.6       66.3       63.9       63.9       64.0
# height              50.6   59.8       50.2       50.8       50.8       52.6
# curb-weight         2191   2535       2811       1713       1819       1837
# engine-type          ohc    ohc        ohc        ohc        ohc        ohc
# num-of-cylinders    four   four       four       four       four       four
# engine-size           98    122        156         92         92         79
# fuel-system         mpfi   2bbl        mfi       1bbl       1bbl       1bbl
# bore                3.03   3.34       3.60       2.91       2.91       2.91
# stroke              3.39   3.46       3.90       3.41       3.41       3.07
# compression-ratio    7.6    8.5        7.0        9.6        9.2       10.1
# horsepower           102     88        145         58         76         60
# peak-rpm            5500   5000       5000       4800       6000       5500
# city-mpg              24     24         19         49         31         38
# highway-mpg           30     30         24         54         38         42
# price               8558   8921      12964       6479       6855       5399
#
#                          33         34     35     36         37         38   \
# symboling                  1          1      0      0          0          0
# normalized-losses        101        101    110     78        106        106
# brand                  honda      honda  honda  honda      honda      honda
# fuel-type                gas        gas    gas    gas        gas        gas
# aspiration               std        std    std    std        std        std
# num-of-doors             two        two   four   four        two        two
# body-style         hatchback  hatchback  sedan  wagon  hatchback  hatchback
# drive-wheels             fwd        fwd    fwd    fwd        fwd        fwd
# engine-location        front      front  front  front      front      front
# wheel-base              93.7       93.7   96.5   96.5       96.5       96.5
# length                 150.0      150.0  163.4  157.1      167.5      167.5
# width                   64.0       64.0   64.0   63.9       65.2       65.2
# height                  52.6       52.6   54.5   58.3       53.3       53.3
# curb-weight             1940       1956   2010   2024       2236       2289
# engine-type              ohc        ohc    ohc    ohc        ohc        ohc
# num-of-cylinders        four       four   four   four       four       four
# engine-size               92         92     92     92        110        110
# fuel-system             1bbl       1bbl   1bbl   1bbl       1bbl       1bbl
# bore                    2.91       2.91   2.91   2.92       3.15       3.15
# stroke                  3.41       3.41   3.41   3.41       3.58       3.58
# compression-ratio        9.2        9.2    9.2    9.2        9.0        9.0
# horsepower                76         76     76     76         86         86
# peak-rpm                6000       6000   6000   6000       5800       5800
# city-mpg                  30         30     30     30         27         27
# highway-mpg               34         34     34     34         33         33
# price                   6529       7129   7295   7295       7895       9095
#
#                      39     40     41     42     43         46      47   \
# symboling              0      0      0      1      0          2       0
# normalized-losses     85     85     85    107  122.0      122.0     145
# brand              honda  honda  honda  honda  isuzu      isuzu  jaguar
# fuel-type            gas    gas    gas    gas    gas        gas     gas
# aspiration           std    std    std    std    std        std     std
# num-of-doors        four   four   four    two   four        two    four
# body-style         sedan  sedan  sedan  sedan  sedan  hatchback   sedan
# drive-wheels         fwd    fwd    fwd    fwd    rwd        rwd     rwd
# engine-location    front  front  front  front  front      front   front
# wheel-base          96.5   96.5   96.5   96.5   94.3       96.0   113.0
# length             175.4  175.4  175.4  169.1  170.7      172.6   199.6
# width               65.2   62.5   65.2   66.0   61.8       65.2    69.6
# height              54.1   54.1   54.1   51.0   53.5       51.4    52.8
# curb-weight         2304   2372   2465   2293   2337       2734    4066
# engine-type          ohc    ohc    ohc    ohc    ohc        ohc    dohc
# num-of-cylinders    four   four   four   four   four       four     six
# engine-size          110    110    110    110    111        119     258
# fuel-system         1bbl   1bbl   mpfi   2bbl   2bbl       spfi    mpfi
# bore                3.15   3.15   3.15   3.15   3.31       3.43    3.63
# stroke              3.58   3.58   3.58   3.58   3.23       3.23    4.17
# compression-ratio    9.0    9.0    9.0    9.1    8.5        9.2     8.1
# horsepower            86     86    101    100     78         90     176
# peak-rpm            5800   5800   5800   5500   4800       5000    4750
# city-mpg              27     27     24     25     24         24      15
# highway-mpg           33     33     28     31     29         29      19
# price               8845  10295  12945  10345   6785      11048   32250
#
#                       48      49         50         51         52     53   \
# symboling               0       0          1          1          1      1
# normalized-losses   122.0   122.0        104        104        104    113
# brand              jaguar  jaguar      mazda      mazda      mazda  mazda
# fuel-type             gas     gas        gas        gas        gas    gas
# aspiration            std     std        std        std        std    std
# num-of-doors         four     two        two        two        two   four
# body-style          sedan   sedan  hatchback  hatchback  hatchback  sedan
# drive-wheels          rwd     rwd        fwd        fwd        fwd    fwd
# engine-location     front   front      front      front      front  front
# wheel-base          113.0   102.0       93.1       93.1       93.1   93.1
# length              199.6   191.7      159.1      159.1      159.1  166.8
# width                69.6    70.6       64.2       64.2       64.2   64.2
# height               52.8    47.8       54.1       54.1       54.1   54.1
# curb-weight          4066    3950       1890       1900       1905   1945
# engine-type          dohc    ohcv        ohc        ohc        ohc    ohc
# num-of-cylinders      six  twelve       four       four       four   four
# engine-size           258     326         91         91         91     91
# fuel-system          mpfi    mpfi       2bbl       2bbl       2bbl   2bbl
# bore                 3.63    3.54       3.03       3.03       3.03   3.03
# stroke               4.17    2.76       3.15       3.15       3.15   3.15
# compression-ratio     8.1    11.5        9.0        9.0        9.0    9.0
# horsepower            176     262         68         68         68     68
# peak-rpm             4750    5000       5000       5000       5000   5000
# city-mpg               15      13         30         31         31     31
# highway-mpg            19      17         31         38         38     38
# price               35550   36000       5195       6095       6795   6695
#
#                      54         55         56         57         58   \
# symboling              1          3          3          3          3
# normalized-losses    113        150        150        150        150
# brand              mazda      mazda      mazda      mazda      mazda
# fuel-type            gas        gas        gas        gas        gas
# aspiration           std        std        std        std        std
# num-of-doors        four        two        two        two        two
# body-style         sedan  hatchback  hatchback  hatchback  hatchback
# drive-wheels         fwd        rwd        rwd        rwd        rwd
# engine-location    front      front      front      front      front
# wheel-base          93.1       95.3       95.3       95.3       95.3
# length             166.8      169.0      169.0      169.0      169.0
# width               64.2       65.7       65.7       65.7       65.7
# height              54.1       49.6       49.6       49.6       49.6
# curb-weight         1950       2380       2380       2385       2500
# engine-type          ohc      rotor      rotor      rotor      rotor
# num-of-cylinders    four        two        two        two        two
# engine-size           91         70         70         70         80
# fuel-system         2bbl       4bbl       4bbl       4bbl       mpfi
# bore                3.08      122.0      122.0      122.0      122.0
# stroke              3.15   3.255423   3.255423   3.255423   3.255423
# compression-ratio    9.0        9.4        9.4        9.4        9.4
# horsepower            68        101        101        101        135
# peak-rpm            5000       6000       6000       6000       6000
# city-mpg              31         17         17         17         16
# highway-mpg           38         23         23         23         23
# price               7395      10945      11845      13645      15645
#
#                          59     60         61     62      63         64   \
# symboling                  1      0          1      0       0          0
# normalized-losses        129    115        129    115   122.0        115
# brand                  mazda  mazda      mazda  mazda   mazda      mazda
# fuel-type                gas    gas        gas    gas  diesel        gas
# aspiration               std    std        std    std     std        std
# num-of-doors             two   four        two   four    four       four
# body-style         hatchback  sedan  hatchback  sedan   sedan  hatchback
# drive-wheels             fwd    fwd        fwd    fwd     fwd        fwd
# engine-location        front  front      front  front   front      front
# wheel-base              98.8   98.8       98.8   98.8    98.8       98.8
# length                 177.8  177.8      177.8  177.8   177.8      177.8
# width                   66.5   66.5       66.5   66.5    66.5       66.5
# height                  53.7   55.5       53.7   55.5    55.5       55.5
# curb-weight             2385   2410       2385   2410    2443       2425
# engine-type              ohc    ohc        ohc    ohc     ohc        ohc
# num-of-cylinders        four   four       four   four    four       four
# engine-size              122    122        122    122     122        122
# fuel-system             2bbl   2bbl       2bbl   2bbl     idi       2bbl
# bore                    3.39   3.39       3.39   3.39    3.39       3.39
# stroke                  3.39   3.39       3.39   3.39    3.39       3.39
# compression-ratio        8.6    8.6        8.6    8.6    22.7        8.6
# horsepower                84     84         84     84      64         84
# peak-rpm                4800   4800       4800   4800    4650       4800
# city-mpg                  26     26         26     26      36         26
# highway-mpg               32     32         32     32      42         32
# price                   8845   8495      10595  10245   10795      11245
#
#                      65      66             67             68             69   \
# symboling              0       0             -1             -1              0
# normalized-losses    118   122.0             93             93             93
# brand              mazda   mazda  mercedes-benz  mercedes-benz  mercedes-benz
# fuel-type            gas  diesel         diesel         diesel         diesel
# aspiration           std     std          turbo          turbo          turbo
# num-of-doors        four    four           four           four            two
# body-style         sedan   sedan          sedan          wagon        hardtop
# drive-wheels         rwd     rwd            rwd            rwd            rwd
# engine-location    front   front          front          front          front
# wheel-base         104.9   104.9          110.0          110.0          106.7
# length             175.0   175.0          190.9          190.9          187.5
# width               66.1    66.1           70.3           70.3           70.3
# height              54.4    54.4           56.5           58.7           54.9
# curb-weight         2670    2700           3515           3750           3495
# engine-type          ohc     ohc            ohc            ohc            ohc
# num-of-cylinders    four    four           five           five           five
# engine-size          140     134            183            183            183
# fuel-system         mpfi     idi            idi            idi            idi
# bore                3.76    3.43           3.58           3.58           3.58
# stroke              3.16    3.64           3.64           3.64           3.64
# compression-ratio    8.0    22.0           21.5           21.5           21.5
# horsepower           120      72            123            123            123
# peak-rpm            5000    4200           4350           4350           4350
# city-mpg              19      31             22             22             22
# highway-mpg           27      39             25             25             25
# price              18280   18344          25552          28248          28176
#
#                              70             71             72             73   \
# symboling                     -1             -1              3              0
# normalized-losses             93          122.0            142          122.0
# brand              mercedes-benz  mercedes-benz  mercedes-benz  mercedes-benz
# fuel-type                 diesel            gas            gas            gas
# aspiration                 turbo            std            std            std
# num-of-doors                four           four            two           four
# body-style                 sedan          sedan    convertible          sedan
# drive-wheels                 rwd            rwd            rwd            rwd
# engine-location            front          front          front          front
# wheel-base                 115.6          115.6           96.6          120.9
# length                     202.6          202.6          180.3          208.1
# width                       71.7           71.7           70.5           71.7
# height                      56.3           56.5           50.8           56.7
# curb-weight                 3770           3740           3685           3900
# engine-type                  ohc           ohcv           ohcv           ohcv
# num-of-cylinders            five          eight          eight          eight
# engine-size                  183            234            234            308
# fuel-system                  idi           mpfi           mpfi           mpfi
# bore                        3.58           3.46           3.46           3.80
# stroke                      3.64           3.10           3.10           3.35
# compression-ratio           21.5            8.3            8.3            8.0
# horsepower                   123            155            155            184
# peak-rpm                    4350           4750           4750           4500
# city-mpg                      22             16             16             14
# highway-mpg                   25             18             18             16
# price                      31600          34184          35056          40960
#
#                              74         75          76          77   \
# symboling                      1          1           2           2
# normalized-losses          122.0      122.0         161         161
# brand              mercedes-benz    mercury  mitsubishi  mitsubishi
# fuel-type                    gas        gas         gas         gas
# aspiration                   std      turbo         std         std
# num-of-doors                 two        two         two         two
# body-style               hardtop  hatchback   hatchback   hatchback
# drive-wheels                 rwd        rwd         fwd         fwd
# engine-location            front      front       front       front
# wheel-base                 112.0      102.7        93.7        93.7
# length                     199.2      178.4       157.3       157.3
# width                       72.0       68.0        64.4        64.4
# height                      55.4       54.8        50.8        50.8
# curb-weight                 3715       2910        1918        1944
# engine-type                 ohcv        ohc         ohc         ohc
# num-of-cylinders           eight       four        four        four
# engine-size                  304        140          92          92
# fuel-system                 mpfi       mpfi        2bbl        2bbl
# bore                        3.80       3.78        2.97        2.97
# stroke                      3.35       3.12        3.23        3.23
# compression-ratio            8.0        8.0         9.4         9.4
# horsepower                   184        175          68          68
# peak-rpm                    4500       5000        5500        5500
# city-mpg                      14         19          37          31
# highway-mpg                   16         24          41          38
# price                      45400      16503        5389        6189
#
#                           78          79          80          81          82   \
# symboling                   2           1           3           3           3
# normalized-losses         161         161         153         153       122.0
# brand              mitsubishi  mitsubishi  mitsubishi  mitsubishi  mitsubishi
# fuel-type                 gas         gas         gas         gas         gas
# aspiration                std       turbo       turbo         std       turbo
# num-of-doors              two         two         two         two         two
# body-style          hatchback   hatchback   hatchback   hatchback   hatchback
# drive-wheels              fwd         fwd         fwd         fwd         fwd
# engine-location         front       front       front       front       front
# wheel-base               93.7        93.0        96.3        96.3        95.9
# length                  157.3       157.3       173.0       173.0       173.2
# width                    64.4        63.8        65.4        65.4        66.3
# height                   50.8        50.8        49.4        49.4        50.2
# curb-weight              2004        2145        2370        2328        2833
# engine-type               ohc         ohc         ohc         ohc         ohc
# num-of-cylinders         four        four        four        four        four
# engine-size                92          98         110         122         156
# fuel-system              2bbl        spdi        spdi        2bbl        spdi
# bore                     2.97        3.03        3.17        3.35        3.58
# stroke                   3.23        3.39        3.46        3.46        3.86
# compression-ratio         9.4         7.6         7.5         8.5         7.0
# horsepower                 68         102         116          88         145
# peak-rpm                 5500        5500        5500        5000        5000
# city-mpg                   31          24          23          25          19
# highway-mpg                38          30          30          32          24
# price                    6669        7689        9959        8499       12629
#
#                           83          84          85          86          87   \
# symboling                   3           3           1           1           1
# normalized-losses       122.0       122.0         125         125         125
# brand              mitsubishi  mitsubishi  mitsubishi  mitsubishi  mitsubishi
# fuel-type                 gas         gas         gas         gas         gas
# aspiration              turbo       turbo         std         std       turbo
# num-of-doors              two         two        four        four        four
# body-style          hatchback   hatchback       sedan       sedan       sedan
# drive-wheels              fwd         fwd         fwd         fwd         fwd
# engine-location         front       front       front       front       front
# wheel-base               95.9        95.9        96.3        96.3        96.3
# length                  173.2       173.2       172.4       172.4       172.4
# width                    66.3        66.3        65.4        65.4        65.4
# height                   50.2        50.2        51.6        51.6        51.6
# curb-weight              2921        2926        2365        2405        2403
# engine-type               ohc         ohc         ohc         ohc         ohc
# num-of-cylinders         four        four        four        four        four
# engine-size               156         156         122         122         110
# fuel-system              spdi        spdi        2bbl        2bbl        spdi
# bore                     3.59        3.59        3.35        3.35        3.17
# stroke                   3.86        3.86        3.46        3.46        3.46
# compression-ratio         7.0         7.0         8.5         8.5         7.5
# horsepower                145         145          88          88         116
# peak-rpm                 5000        5000        5000        5000        5500
# city-mpg                   19          19          25          25          23
# highway-mpg                24          24          32          32          30
# price                   14869       14489        6989        8189        9279
#
#                           88      89      90      91      92      93      94   \
# symboling                  -1       1       1       1       1       1       1
# normalized-losses         137     128     128     128     122     103     128
# brand              mitsubishi  nissan  nissan  nissan  nissan  nissan  nissan
# fuel-type                 gas     gas  diesel     gas     gas     gas     gas
# aspiration                std     std     std     std     std     std     std
# num-of-doors             four     two     two     two    four    four     two
# body-style              sedan   sedan   sedan   sedan   sedan   wagon   sedan
# drive-wheels              fwd     fwd     fwd     fwd     fwd     fwd     fwd
# engine-location         front   front   front   front   front   front   front
# wheel-base               96.3    94.5    94.5    94.5    94.5    94.5    94.5
# length                  172.4   165.3   165.3   165.3   165.3   170.2   165.3
# width                    65.4    63.8    63.8    63.8    63.8    63.8    63.8
# height                   51.6    54.5    54.5    54.5    54.5    53.5    54.5
# curb-weight              2403    1889    2017    1918    1938    2024    1951
# engine-type               ohc     ohc     ohc     ohc     ohc     ohc     ohc
# num-of-cylinders         four    four    four    four    four    four    four
# engine-size               110      97     103      97      97      97      97
# fuel-system              spdi    2bbl     idi    2bbl    2bbl    2bbl    2bbl
# bore                     3.17    3.15    2.99    3.15    3.15    3.15    3.15
# stroke                   3.46    3.29    3.47    3.29    3.29    3.29    3.29
# compression-ratio         7.5     9.4    21.9     9.4     9.4     9.4     9.4
# horsepower                116      69      55      69      69      69      69
# peak-rpm                 5500    5200    4800    5200    5200    5200    5200
# city-mpg                   23      31      45      31      31      31      31
# highway-mpg                30      37      50      37      37      37      37
# price                    9279    5499    7099    6649    6849    7349    7299
#
#                          95      96      97       98         99      100  \
# symboling                  1       1       1        2          0       0
# normalized-losses        128     122     103      168        106     106
# brand                 nissan  nissan  nissan   nissan     nissan  nissan
# fuel-type                gas     gas     gas      gas        gas     gas
# aspiration               std     std     std      std        std     std
# num-of-doors             two    four    four      two       four    four
# body-style         hatchback   sedan   wagon  hardtop  hatchback   sedan
# drive-wheels             fwd     fwd     fwd      fwd        fwd     fwd
# engine-location        front   front   front    front      front   front
# wheel-base              94.5    94.5    94.5     95.1       97.2    97.2
# length                 165.6   165.3   170.2    162.4      173.4   173.4
# width                   63.8    63.8    63.8     63.8       65.2    65.2
# height                  53.3    54.5    53.5     53.3       54.7    54.7
# curb-weight             2028    1971    2037     2008       2324    2302
# engine-type              ohc     ohc     ohc      ohc        ohc     ohc
# num-of-cylinders        four    four    four     four       four    four
# engine-size               97      97      97       97        120     120
# fuel-system             2bbl    2bbl    2bbl     2bbl       2bbl    2bbl
# bore                    3.15    3.15    3.15     3.15       3.33    3.33
# stroke                  3.29    3.29    3.29     3.29       3.47    3.47
# compression-ratio        9.4     9.4     9.4      9.4        8.5     8.5
# horsepower                69      69      69       69         97      97
# peak-rpm                5200    5200    5200     5200       5200    5200
# city-mpg                  31      31      31       31         27      27
# highway-mpg               37      37      37       37         34      34
# price                   7799    7499    7999     8249       8949    9549
#
#                       101     102     103        104        105        106  \
# symboling               0       0       0          3          3          1
# normalized-losses     128     108     108        194        194        231
# brand              nissan  nissan  nissan     nissan     nissan     nissan
# fuel-type             gas     gas     gas        gas        gas        gas
# aspiration            std     std     std        std      turbo        std
# num-of-doors         four    four    four        two        two        two
# body-style          sedan   wagon   sedan  hatchback  hatchback  hatchback
# drive-wheels          fwd     fwd     fwd        rwd        rwd        rwd
# engine-location     front   front   front      front      front      front
# wheel-base          100.4   100.4   100.4       91.3       91.3       99.2
# length              181.7   184.6   184.6      170.7      170.7      178.5
# width                66.5    66.5    66.5       67.9       67.9       67.9
# height               55.1    56.1    55.1       49.7       49.7       49.7
# curb-weight          3095    3296    3060       3071       3139       3139
# engine-type          ohcv    ohcv    ohcv       ohcv       ohcv       ohcv
# num-of-cylinders      six     six     six        six        six        six
# engine-size           181     181     181        181        181        181
# fuel-system          mpfi    mpfi    mpfi       mpfi       mpfi       mpfi
# bore                 3.43    3.43    3.43       3.43       3.43       3.43
# stroke               3.27    3.27    3.27       3.27       3.27       3.27
# compression-ratio     9.0     9.0     9.0        9.0        7.8        9.0
# horsepower            152     152     152        160        200        160
# peak-rpm             5200    5200    5200       5200       5200       5200
# city-mpg               17      17      19         19         17         19
# highway-mpg            22      22      25         25         23         25
# price               13499   14399   13499      17199      19699      18399
#
#                       107     108     109     110     111     112     113  \
# symboling               0       0       0       0       0       0       0
# normalized-losses     161     161   122.0   122.0     161     161   122.0
# brand              peugot  peugot  peugot  peugot  peugot  peugot  peugot
# fuel-type             gas  diesel     gas  diesel     gas  diesel     gas
# aspiration            std   turbo     std   turbo     std   turbo     std
# num-of-doors         four    four    four    four    four    four    four
# body-style          sedan   sedan   wagon   wagon   sedan   sedan   wagon
# drive-wheels          rwd     rwd     rwd     rwd     rwd     rwd     rwd
# engine-location     front   front   front   front   front   front   front
# wheel-base          107.9   107.9   114.2   114.2   107.9   107.9   114.2
# length              186.7   186.7   198.9   198.9   186.7   186.7   198.9
# width                68.4    68.4    68.4    68.4    68.4    68.4    68.4
# height               56.7    56.7    58.7    58.7    56.7    56.7    56.7
# curb-weight          3020    3197    3230    3430    3075    3252    3285
# engine-type             l       l       l       l       l       l       l
# num-of-cylinders     four    four    four    four    four    four    four
# engine-size           120     152     120     152     120     152     120
# fuel-system          mpfi     idi    mpfi     idi    mpfi     idi    mpfi
# bore                 3.46    3.70    3.46    3.70    3.46    3.70    3.46
# stroke               3.19    3.52    3.19    3.52    2.19    3.52    2.19
# compression-ratio     8.4    21.0     8.4    21.0     8.4    21.0     8.4
# horsepower             97      95      97      95      95      95      95
# peak-rpm             5000    4150    5000    4150    5000    4150    5000
# city-mpg               19      28      19      25      19      28      19
# highway-mpg            24      33      24      25      24      33      24
# price               11900   13200   12440   13860   15580   16900   16695
#
#                       114     115     116     117        118        119  \
# symboling               0       0       0       0          1          1
# normalized-losses   122.0     161     161     161        119        119
# brand              peugot  peugot  peugot  peugot   plymouth   plymouth
# fuel-type          diesel     gas  diesel     gas        gas        gas
# aspiration          turbo     std   turbo   turbo        std      turbo
# num-of-doors         four    four    four    four        two        two
# body-style          wagon   sedan   sedan   sedan  hatchback  hatchback
# drive-wheels          rwd     rwd     rwd     rwd        fwd        fwd
# engine-location     front   front   front   front      front      front
# wheel-base          114.2   107.9   107.9   108.0       93.7       93.7
# length              198.9   186.7   186.7   186.7      157.3      157.3
# width                68.4    68.4    68.4    68.3       63.8       63.8
# height               58.7    56.7    56.7    56.0       50.8       50.8
# curb-weight          3485    3075    3252    3130       1918       2128
# engine-type             l       l       l       l        ohc        ohc
# num-of-cylinders     four    four    four    four       four       four
# engine-size           152     120     152     134         90         98
# fuel-system           idi    mpfi     idi    mpfi       2bbl       spdi
# bore                 3.70    3.46    3.70    3.61       2.97       3.03
# stroke               3.52    3.19    3.52    3.21       3.23       3.39
# compression-ratio    21.0     8.4    21.0     7.0        9.4        7.6
# horsepower             95      97      95     142         68        102
# peak-rpm             4150    5000    4150    5600       5500       5500
# city-mpg               25      19      28      18         37         24
# highway-mpg            25      24      33      24         41         30
# price               17075   16630   17950   18150       5572       7957
#
#                          120       121       122       123        124  \
# symboling                  1         1         1        -1          3
# normalized-losses        154       154       154        74      122.0
# brand               plymouth  plymouth  plymouth  plymouth   plymouth
# fuel-type                gas       gas       gas       gas        gas
# aspiration               std       std       std       std      turbo
# num-of-doors            four      four      four      four        two
# body-style         hatchback     sedan     sedan     wagon  hatchback
# drive-wheels             fwd       fwd       fwd       fwd        rwd
# engine-location        front     front     front     front      front
# wheel-base              93.7      93.7      93.7     103.3       95.9
# length                 157.3     167.3     167.3     174.6      173.2
# width                   63.8      63.8      63.8      64.6       66.3
# height                  50.6      50.8      50.8      59.8       50.2
# curb-weight             1967      1989      2191      2535       2818
# engine-type              ohc       ohc       ohc       ohc        ohc
# num-of-cylinders        four      four      four      four       four
# engine-size               90        90        98       122        156
# fuel-system             2bbl      2bbl      2bbl      2bbl       spdi
# bore                    2.97      2.97      2.97      3.35       3.59
# stroke                  3.23      3.23      3.23      3.46       3.86
# compression-ratio        9.4       9.4       9.4       8.5        7.0
# horsepower                68        68        68        88        145
# peak-rpm                5500      5500      5500      5000       5000
# city-mpg                  31        31        31        24         19
# highway-mpg               38        38        38        30         24
# price                   6229      6692      7609      8921      12764
#
#                          125      126      127          128      130  \
# symboling                  3        3        3            3        0
# normalized-losses        186    122.0    122.0        122.0    122.0
# brand                porsche  porsche  porsche      porsche  renault
# fuel-type                gas      gas      gas          gas      gas
# aspiration               std      std      std          std      std
# num-of-doors             two      two      two          two     four
# body-style         hatchback  hardtop  hardtop  convertible    wagon
# drive-wheels             rwd      rwd      rwd          rwd      fwd
# engine-location        front     rear     rear         rear    front
# wheel-base              94.5     89.5     89.5         89.5     96.1
# length                 168.9    168.9    168.9        168.9    181.5
# width                   68.3     65.0     65.0         65.0     66.5
# height                  50.2     51.6     51.6         51.6     55.2
# curb-weight             2778     2756     2756         2800     2579
# engine-type              ohc     ohcf     ohcf         ohcf      ohc
# num-of-cylinders        four      six      six          six     four
# engine-size              151      194      194          194      132
# fuel-system             mpfi     mpfi     mpfi         mpfi     mpfi
# bore                    3.94     3.74     3.74         3.74     3.46
# stroke                  3.11     2.90     2.90         2.90     3.90
# compression-ratio        9.5      9.5      9.5          9.5      8.7
# horsepower               143      207      207          207      NaN
# peak-rpm                5500     5900     5900         5900      NaN
# city-mpg                  19       17       17           17       23
# highway-mpg               27       25       25           25       31
# price                  22018    32528    34028        37028     9295
#
#                          131        132    133        134    135        136  \
# symboling                  2          3      2          3      2          3
# normalized-losses      122.0        150    104        150    104        150
# brand                renault       saab   saab       saab   saab       saab
# fuel-type                gas        gas    gas        gas    gas        gas
# aspiration               std        std    std        std    std      turbo
# num-of-doors             two        two   four        two   four        two
# body-style         hatchback  hatchback  sedan  hatchback  sedan  hatchback
# drive-wheels             fwd        fwd    fwd        fwd    fwd        fwd
# engine-location        front      front  front      front  front      front
# wheel-base              96.1       99.1   99.1       99.1   99.1       99.1
# length                 176.8      186.6  186.6      186.6  186.6      186.6
# width                   66.6       66.5   66.5       66.5   66.5       66.5
# height                  50.5       56.1   56.1       56.1   56.1       56.1
# curb-weight             2460       2658   2695       2707   2758       2808
# engine-type              ohc        ohc    ohc        ohc    ohc       dohc
# num-of-cylinders        four       four   four       four   four       four
# engine-size              132        121    121        121    121        121
# fuel-system             mpfi       mpfi   mpfi       mpfi   mpfi       mpfi
# bore                    3.46       3.54   3.54       2.54   3.54       3.54
# stroke                  3.90       3.07   3.07       2.07   3.07       3.07
# compression-ratio        8.7       9.31    9.3        9.3    9.3        9.0
# horsepower               NaN        110    110        110    110        160
# peak-rpm                 NaN       5250   5250       5250   5250       5500
# city-mpg                  23         21     21         21     21         19
# highway-mpg               31         28     28         28     28         26
# price                   9895      11850  12170      15040  15510      18150
#
# ...
# city-mpg               30         30      34         38      38         28
# highway-mpg            37         37      36         47      47         34
# price                6938       7198    7898       7788    7738       8358
#
#                       162     163        164     165        166      167  \
# symboling               0       1          1       1          1        2
# normalized-losses      91     168        168     168        168      134
# brand              toyota  toyota     toyota  toyota     toyota   toyota
# fuel-type             gas     gas        gas     gas        gas      gas
# aspiration            std     std        std     std        std      std
# num-of-doors         four     two        two     two        two      two
# body-style          sedan   sedan  hatchback   sedan  hatchback  hardtop
# drive-wheels          fwd     rwd        rwd     rwd        rwd      rwd
# engine-location     front   front      front   front      front    front
# wheel-base           95.7    94.5       94.5    94.5       94.5     98.4
# length              166.3   168.7      168.7   168.7      168.7    176.2
# width                64.4    64.0       64.0    64.0       64.0     65.6
# height               52.8    52.6       52.6    52.6       52.6     52.0
# curb-weight          2140    2169       2204    2265       2300     2540
# engine-type           ohc     ohc        ohc    dohc       dohc      ohc
# num-of-cylinders     four    four       four    four       four     four
# engine-size            98      98         98      98         98      146
# fuel-system          2bbl    2bbl       2bbl    mpfi       mpfi     mpfi
# bore                 3.19    3.19       3.19    3.24       3.24     3.62
# stroke               3.03    3.03       3.03    3.08       3.08     3.50
# compression-ratio     9.0     9.0        9.0     9.4        9.4      9.3
# horsepower             70      70         70     112        112      116
# peak-rpm             4800    4800       4800    6600       6600     4800
# city-mpg               28      29         29      26         26       24
# highway-mpg            34      34         34      29         29       30
# price                9258    8058       8238    9298       9538     8449
#
#                        168        169      170        171          172  \
# symboling                2          2        2          2            2
# normalized-losses      134        134      134        134          134
# brand               toyota     toyota   toyota     toyota       toyota
# fuel-type              gas        gas      gas        gas          gas
# aspiration             std        std      std        std          std
# num-of-doors           two        two      two        two          two
# body-style         hardtop  hatchback  hardtop  hatchback  convertible
# drive-wheels           rwd        rwd      rwd        rwd          rwd
# engine-location      front      front    front      front        front
# wheel-base            98.4       98.4     98.4       98.4         98.4
# length               176.2      176.2    176.2      176.2        176.2
# width                 65.6       65.6     65.6       65.6         65.6
# height                52.0       52.0     52.0       52.0         53.0
# curb-weight           2536       2551     2679       2714         2975
# engine-type            ohc        ohc      ohc        ohc          ohc
# num-of-cylinders      four       four     four       four         four
# engine-size            146        146      146        146          146
# fuel-system           mpfi       mpfi     mpfi       mpfi         mpfi
# bore                  3.62       3.62     3.62       3.62         3.62
# stroke                3.50       3.50     3.50       3.50         3.50
# compression-ratio      9.3        9.3      9.3        9.3          9.3
# horsepower             116        116      116        116          116
# peak-rpm              4800       4800     4800       4800         4800
# city-mpg                24         24       24         24           24
# highway-mpg             30         30       30         30           30
# price                 9639       9989    11199      11549        17669
#
#                       173     174        175     176        177        178  \
# symboling              -1      -1         -1      -1         -1          3
# normalized-losses      65      65         65      65         65        197
# brand              toyota  toyota     toyota  toyota     toyota     toyota
# fuel-type             gas  diesel        gas     gas        gas        gas
# aspiration            std   turbo        std     std        std        std
# num-of-doors         four    four       four    four       four        two
# body-style          sedan   sedan  hatchback   sedan  hatchback  hatchback
# drive-wheels          fwd     fwd        fwd     fwd        fwd        rwd
# engine-location     front   front      front   front      front      front
# wheel-base          102.4   102.4      102.4   102.4      102.4      102.9
# length              175.6   175.6      175.6   175.6      175.6      183.5
# width                66.5    66.5       66.5    66.5       66.5       67.7
# height               54.9    54.9       53.9    54.9       53.9       52.0
# curb-weight          2326    2480       2414    2414       2458       2976
# engine-type           ohc     ohc        ohc     ohc        ohc       dohc
# num-of-cylinders     four    four       four    four       four        six
# engine-size           122     110        122     122        122        171
# fuel-system          mpfi     idi       mpfi    mpfi       mpfi       mpfi
# bore                 3.31    3.27       3.31    3.31       3.31       3.27
# stroke               3.54    3.35       3.54    3.54       3.54       3.35
# compression-ratio     8.7    22.5        8.7     8.7        8.7        9.3
# horsepower             92      73         92      92         92        161
# peak-rpm             4200    4500       4200    4200       4200       5200
# city-mpg               29      30         27      27         27         20
# highway-mpg            34      33         32      32         32         24
# price                8948   10698       9988   10898      11248      16558
#
#                          179     180     181         182         183  \
# symboling                  3      -1      -1           2           2
# normalized-losses        197      90   122.0         122         122
# brand                 toyota  toyota  toyota  volkswagen  volkswagen
# fuel-type                gas     gas     gas      diesel         gas
# aspiration               std     std     std         std         std
# num-of-doors             two    four    four         two         two
# body-style         hatchback   sedan   wagon       sedan       sedan
# drive-wheels             rwd     rwd     rwd         fwd         fwd
# engine-location        front   front   front       front       front
# wheel-base             102.9   104.5   104.5        97.3        97.3
# length                 183.5   187.8   187.8       171.7       171.7
# width                   67.7    66.5    66.5        65.5        65.5
# height                  52.0    54.1    54.1        55.7        55.7
# curb-weight             3016    3131    3151        2261        2209
# engine-type             dohc    dohc    dohc         ohc         ohc
# num-of-cylinders         six     six     six        four        four
# engine-size              171     171     161          97         109
# fuel-system             mpfi    mpfi    mpfi         idi        mpfi
# bore                    3.27    3.27    3.27        3.01        3.19
# stroke                  3.35    3.35    3.35        3.40        3.40
# compression-ratio        9.3     9.2     9.2        23.0         9.0
# horsepower               161     156     156          52          85
# peak-rpm                5200    5200    5200        4800        5250
# city-mpg                  19      20      19          37          27
# highway-mpg               24      24      24          46          34
# price                  15998   15690   15750        7775        7975
#
#                           184         185         186         187         188  \
# symboling                   2           2           2           2           2
# normalized-losses          94          94          94          94          94
# brand              volkswagen  volkswagen  volkswagen  volkswagen  volkswagen
# fuel-type              diesel         gas         gas      diesel         gas
# aspiration                std         std         std       turbo         std
# num-of-doors             four        four        four        four        four
# body-style              sedan       sedan       sedan       sedan       sedan
# drive-wheels              fwd         fwd         fwd         fwd         fwd
# engine-location         front       front       front       front       front
# wheel-base               97.3        97.3        97.3        97.3        97.3
# length                  171.7       171.7       171.7       171.7       171.7
# width                    65.5        65.5        65.5        65.5        65.5
# height                   55.7        55.7        55.7        55.7        55.7
# curb-weight              2264        2212        2275        2319        2300
# engine-type               ohc         ohc         ohc         ohc         ohc
# num-of-cylinders         four        four        four        four        four
# engine-size                97         109         109          97         109
# fuel-system               idi        mpfi        mpfi         idi        mpfi
# bore                     3.01        3.19        3.19        3.01        3.19
# stroke                   3.40        3.40        3.40        3.40        3.40
# compression-ratio        23.0         9.0         9.0        23.0        10.0
# horsepower                 52          85          85          68         100
# peak-rpm                 4800        5250        5250        4500        5500
# city-mpg                   37          27          27          37          26
# highway-mpg                46          34          34          42          32
# price                    7995        8195        8495        9495        9995
#
#                            189         190         191         192  \
# symboling                    3           3           0           0
# normalized-losses        122.0         256       122.0       122.0
# brand               volkswagen  volkswagen  volkswagen  volkswagen
# fuel-type                  gas         gas         gas      diesel
# aspiration                 std         std         std       turbo
# num-of-doors               two         two        four        four
# body-style         convertible   hatchback       sedan       sedan
# drive-wheels               fwd         fwd         fwd         fwd
# engine-location          front       front       front       front
# wheel-base                94.5        94.5       100.4       100.4
# length                   159.3       165.7       180.2       180.2
# width                     64.2        64.0        66.9        66.9
# height                    55.6        51.4        55.1        55.1
# curb-weight               2254        2221        2661        2579
# engine-type                ohc         ohc         ohc         ohc
# num-of-cylinders          four        four        five        four
# engine-size                109         109         136          97
# fuel-system               mpfi        mpfi        mpfi         idi
# bore                      3.19        3.19        3.19        3.01
# stroke                    3.40        3.40        3.40        3.40
# compression-ratio          8.5         8.5         8.5        23.0
# horsepower                  90          90         110          68
# peak-rpm                  5500        5500        5500        4500
# city-mpg                    24          24          19          33
# highway-mpg                 29          29          24          38
# price                    11595        9980       13295       13845
#
#                           193    194    195    196    197    198    199  \
# symboling                   0     -2     -1     -2     -1     -2     -1
# normalized-losses       122.0    103     74    103     74    103     74
# brand              volkswagen  volvo  volvo  volvo  volvo  volvo  volvo
# fuel-type                 gas    gas    gas    gas    gas    gas    gas
# aspiration                std    std    std    std    std  turbo  turbo
# num-of-doors             four   four   four   four   four   four   four
# body-style              wagon  sedan  wagon  sedan  wagon  sedan  wagon
# drive-wheels              fwd    rwd    rwd    rwd    rwd    rwd    rwd
# engine-location         front  front  front  front  front  front  front
# wheel-base              100.4  104.3  104.3  104.3  104.3  104.3  104.3
# length                  183.1  188.8  188.8  188.8  188.8  188.8  188.8
# width                    66.9   67.2   67.2   67.2   67.2   67.2   67.2
# height                   55.1   56.2   57.5   56.2   57.5   56.2   57.5
# curb-weight              2563   2912   3034   2935   3042   3045   3157
# engine-type               ohc    ohc    ohc    ohc    ohc    ohc    ohc
# num-of-cylinders         four   four   four   four   four   four   four
# engine-size               109    141    141    141    141    130    130
# fuel-system              mpfi   mpfi   mpfi   mpfi   mpfi   mpfi   mpfi
# bore                     3.19   3.78   3.78   3.78   3.78   3.62   3.62
# stroke                   3.40   3.15   3.15   3.15   3.15   3.15   3.15
# compression-ratio         9.0    9.5    9.5    9.5    9.5    7.5    7.5
# horsepower                 88    114    114    114    114    162    162
# peak-rpm                 5500   5400   5400   5400   5400   5100   5100
# city-mpg                   25     23     23     24     24     17     17
# highway-mpg                31     28     28     28     28     22     22
# price                   12290  12940  13415  15985  16515  18420  18950
#
#                      200    201    202     203    204
# symboling             -1     -1     -1      -1     -1
# normalized-losses     95     95     95      95     95
# brand              volvo  volvo  volvo   volvo  volvo
# fuel-type            gas    gas    gas  diesel    gas
# aspiration           std  turbo    std   turbo  turbo
# num-of-doors        four   four   four    four   four
# body-style         sedan  sedan  sedan   sedan  sedan
# drive-wheels         rwd    rwd    rwd     rwd    rwd
# engine-location    front  front  front   front  front
# wheel-base         109.1  109.1  109.1   109.1  109.1
# length             188.8  188.8  188.8   188.8  188.8
# width               68.9   68.8   68.9    68.9   68.9
# height              55.5   55.5   55.5    55.5   55.5
# curb-weight         2952   3049   3012    3217   3062
# engine-type          ohc    ohc   ohcv     ohc    ohc
# num-of-cylinders    four   four    six     six   four
# engine-size          141    141    173     145    141
# fuel-system         mpfi   mpfi   mpfi     idi   mpfi
# bore                3.78   3.78   3.58    3.01   3.78
# stroke              3.15   3.15   2.87    3.40   3.15
# compression-ratio    9.5    8.7    8.8    23.0    9.5
# horsepower           114    160    134     106    114
# peak-rpm            5400   5300   5500    4800   5400
# city-mpg              23     19     18      26     19
# highway-mpg           28     25     23      27     25
# price              16845  19045  21485   22470  22625

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    object
#  2   brand              201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
#  16  engine-size        201 non-null    int64
#  17  fuel-system        201 non-null    object
#  18  bore               201 non-null    object
#  19  stroke             201 non-null    object
#  20  compression-ratio  201 non-null    float64
#  21  horsepower         199 non-null    object
#  22  peak-rpm           199 non-null    object
#  23  city-mpg           201 non-null    int64
#  24  highway-mpg        201 non-null    int64
#  25  price              201 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 50.5+ KB

# %%
df['horsepower'] = df['horsepower'].astype('int')

# %%
df['horsepower'].plot(kind='area',figsize=(15,5), title='Horsepower')
# Out:
# <AxesSubplot: title={'center': 'Horsepower'}>

# %%
df.sort_values(by='price', inplace=True,ascending=False)

# %%
df.plot(kind='scatter',x='horsepower', y='price',figsize=(15,10))
# Out:
# <AxesSubplot: xlabel='horsepower', ylabel='price'>
